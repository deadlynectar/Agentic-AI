# %%
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI

load_dotenv()
# Out:
# True

# %%
llm = ChatGoogleGenerativeAI(model="gemini-3.1-flash-lite")
response = llm.invoke("Keyword search is better or semantic serch?")
print(response.text)
# Out:
# The answer is that neither is strictly "better"—they serve different purposes. In modern systems, **the best approach is almost always a hybrid of both.**
#
# Here is the breakdown of why you would choose one over the other, and why combining them is the industry standard.
#
# ---
#
# ### 1. Keyword Search (Lexical Search)
# *Examples: BM25, TF-IDF, Elasticsearch/Lucene standard search.*
#
# *   **How it works:** It looks for exact matches of words or phrases. If you search for "Apple iPhone 15," it looks for documents containing those exact terms.
# *   **Strengths:**
#     *   **Precision:** If you search for a specific product serial number, a name, or a technical term, keyword search will find exactly that.
#     *   **Predictability:** It is easy to explain why a result appeared (e.g., "The word 'iPhone' appeared 5 times in this document").
#     *   **Efficiency:** It is computationally inexpensive and very fast.
# *   **Weaknesses:**
#     *   **Vocabulary Mismatch:** If you search for "mobile phone" but the document uses the word "cellphone," keyword search will likely fail.
#     *   **No Context:** It cannot understand intent. It treats "bank" (the river) and "bank" (the financial institution) as identical.
#
# ### 2. Semantic Search (Vector Search)
# *Examples: Dense vector embeddings (OpenAI, Cohere, Pinecone).*
#
# *   **How it works:** It converts text into numerical "vectors" (lists of numbers) that represent the *meaning* of the words. It searches by finding content that is mathematically "close" in concept, even if the words are different.
# *   **Strengths:**
#     *   **Conceptual Understanding:** It understands that "laptop" and "notebook" are related.
#     *   **Handling Intent:** It can handle natural language queries (e.g., "How do I fix a leaky faucet?" will find documents about "plumbing repairs").
#     *   **Multilingual Support:** It can often match a search in English to a document in Spanish because the concepts map to the same vector space.
# *   **Weaknesses:**
#     *   **Recall Issues:** It can sometimes be *too* broad, returning irrelevant results because they are "conceptually similar" but not what the user specifically wanted.
#     *   **Failure on Specificity:** It often struggles with rare words, acronyms, or specific codes (e.g., a specific part number like "XJ-900-B").
#
# ---
#
# ### Comparison Table
#
# | Feature | Keyword Search | Semantic Search |
# | :--- | :--- | :--- |
# | **Matching Type** | Exact word match | Conceptual/Meaning match |
# | **Best for** | Names, IDs, technical specs | Queries, intent, natural language |
# | **Failure Mode** | Synonyms (misses them) | Specificity (gets too broad) |
# | **Complexity** | Low | High |
#
# ---
#
# ### The Winner: Hybrid Search
# Most top-tier search engines (like Google, or those using Elasticsearch/OpenSearch) use **Hybrid Search**.
#
# **How it works:**
# 1.  **Run both:** The system performs a keyword search and a semantic vector search simultaneously.
# 2.  **RRF (Reciprocal Rank Fusion):** It combines the results from both methods, giving weight to results that appear highly in both lists.
#
# **Why use Hybrid?**
# *   If a user types a **specific model number**, the Keyword Search brings it to the top.
# *   If a user types a **vague question** (e.g., "Why is my computer running slow?"), the Semantic Search brings relevant articles to the top.
#
# ### Recommendation
# *   **Choose Keyword Search if:** You are building an e-commerce catalog search for specific SKUs, a dictionary, or a legal database where the exact wording is mandatory.
# *   **Choose Semantic Search if:** You are building a chatbot, a FAQ system, or a content exploration tool where the user's intent matters more than exact keywords.
# *   **Choose Hybrid Search if:** You are building a professional-grade search engine where user satisfaction is the top priority.

# %%
response = llm.invoke([
    ["system", "You are helpful assistant that answers in short less than 5 line"],
    ["human", "Keyword search is better or semantic serch?"]
])
print(response.text)
# Out:
# Keyword search is better for exact matches and technical terms. Semantic search is better for understanding intent and context. The best approach is usually a hybrid model that combines both.

# %%
from langchain_groq import ChatGroq

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(model="qwen/qwen3-32b", reasoning_format="parsed")
messages = [
    (
        "system",
        "You are helpful assistant that answers in short less than 5 line",
    ),
    (
        "human",
        "Keyword search is better or semantic serch?"
    ),
]
ai_msg = llm.invoke(messages)
print(ai_msg.content)
# Out:
# Keyword search is better for **precise, specific queries** where exact terms matter (e.g., code snippets, product IDs). Semantic search excels in **understanding context and intent**, delivering broader, more nuanced results (e.g., "best running shoes" vs. exact brand names). Use **keyword** for speed and specificity, **semantic** for complex or ambiguous needs.
