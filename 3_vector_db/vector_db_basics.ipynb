# %%
import chromadb
client = chromadb.Client()

# %%
collection = client.create_collection("news")

# %%
collection.add(
    ids=["id1", "id2", "id3", "id4"],
    documents=[
        "Apple is leading in a smart phone game with iPhone sales up by 35%",
        "Tesla booked a minor profit of 1 billion $ in Q2",
        "Apples are high in fiber, vitamin C, and various antioxidants",
        "SpaceX got NASA contract worth 10 billion $",
    ]
)

# %%
data=collection.get(
    include=["documents","embeddings", "metadatas"]
)
for i, emb in enumerate(data["embeddings"]):
    print(f"\nDocument: {i+1}")
    print("text:", data["documents"][i])
    print("Embedding length:", len(emb))
    print("First  10 values:", emb[:10])
# Out:
# Document: 1
# text: Apple is leading in a smart phone game with iPhone sales up by 35%
# Embedding length: 384
# First  10 values: [ 0.03640455  0.01021043  0.08642427 -0.12735227 -0.0189593   0.00309626
#   0.01671749  0.05566164  0.02376827  0.11325454]
#
# Document: 2
# text: Tesla booked a minor profit of 1 billion $ in Q2
# Embedding length: 384
# First  10 values: [ 0.03228293  0.08888534  0.02695828  0.07444268 -0.06773709 -0.03529557
#  -0.02407435  0.10166311  0.02283029  0.02386423]
#
# Document: 3
# text: Apples are high in fiber, vitamin C, and various antioxidants
# Embedding length: 384
# First  10 values: [ 0.04512431 -0.0314501   0.01100095  0.08058898  0.00119942  0.02187003
#  -0.00926964 -0.01325599  0.00425174  0.02350491]
#
# Document: 4
# text: SpaceX got NASA contract worth 10 billion $
# Embedding length: 384
# First  10 values: [-0.02309863  0.03526217  0.06101783 -0.02734388 -0.08042093 -0.02970157
#   0.07421495  0.05592685  0.02907891  0.07048371]

# %%
results = collection.query(
    query_texts=["This is a query related to Elon Musk"],
    n_results=2
)
print(results)
# Out:
# {'ids': [['id2', 'id4']], 'embeddings': None, 'documents': [['Tesla booked a minor profit of 1 billion $ in Q2', 'SpaceX got NASA contract worth 10 billion $']], 'uris': None, 'included': ['metadatas', 'documents', 'distances'], 'data': None, 'metadatas': [[None, None]], 'distances': [[1.5166926383972168, 1.5598335266113281]]}

# %%
results = collection.query(
    query_texts=["I love iPad"],
    n_results=2
)
print(results)
# Out:
# {'ids': [['id1', 'id3']], 'embeddings': None, 'documents': [['Apple is leading in a smart phone game with iPhone sales up by 35%', 'Apples are high in fiber, vitamin C, and various antioxidants']], 'uris': None, 'included': ['metadatas', 'documents', 'distances'], 'data': None, 'metadatas': [[None, None]], 'distances': [[1.4372706413269043, 1.6695863008499146]]}

# %%
results = collection.query(
    query_texts=["Tips for improving health"],
    n_results=2
)
print(results)
# Out:
# {'ids': [['id3', 'id1']], 'embeddings': None, 'documents': [['Apples are high in fiber, vitamin C, and various antioxidants', 'Apple is leading in a smart phone game with iPhone sales up by 35%']], 'uris': None, 'included': ['metadatas', 'documents', 'distances'], 'data': None, 'metadatas': [[None, None]], 'distances': [[1.5245025157928467, 1.9163594245910645]]}
